# %%
import pickle
with open("pkls/results_gse_ibm_bangkok.pkl", "rb") as f:
    results_bangkok = pickle.load(f)

# %%
results_bangkok
# Out:
# {'theoretical': {'energy': -4.758770483143625,
#   'eig_vals': array([ 4.75877048+0.j, -4.75877048+0.j, -4.06417777+0.j,  2.75877048+0.j,
#          -2.06417777+0.j, -1.69459271+0.j,  2.06417777+0.j, -0.30540729+0.j,
#           0.30540729+0.j,  4.06417777+0.j, -2.75877048+0.j, -1.        +0.j,
#           1.69459271+0.j,  1.        +0.j,  1.        +0.j, -1.        +0.j])},
#  'raw': {'eig_vals': None, 'energy': -4.144775390625},
#  'fault-subspace': {'eig_vals': array([ 1.74996686-0.j, -0.79269041+0.j, -4.02423125+0.j]),
#   'eig_vecs': array([[-0.87449798+0.j, -0.21269575+0.j,  0.00747387+0.j],
#          [ 0.4137628 +0.j,  0.29112762+0.j,  0.57718775+0.j],
#          [ 0.2530882 +0.j,  0.93274071+0.j, -0.81657728+0.j]]),
#   'H_tilde': array([[ 0.01611328+0.j,  0.02490234+0.j, -0.03894043+0.j],
#          [ 0.05541992+0.j,  0.00256348+0.j, -0.00463867+0.j],
#          [-0.0123291 +0.j, -0.02575684+0.j, -0.02832031+0.j]]),
# ...

# %%
import pickle
with open("pkls/results_gse_ibm_ithaca.pkl", "rb") as f:
    results_ithaca = pickle.load(f)

# %%
results_ithaca
# Out:
# {'theoretical': {'energy': -4.758770483143625,
#   'eig_vals': array([ 4.75877048+0.j, -4.75877048+0.j, -4.06417777+0.j,  2.75877048+0.j,
#          -2.06417777+0.j, -1.69459271+0.j,  2.06417777+0.j, -0.30540729+0.j,
#           0.30540729+0.j,  4.06417777+0.j, -2.75877048+0.j, -1.        +0.j,
#           1.69459271+0.j,  1.        +0.j,  1.        +0.j, -1.        +0.j])},
#  'raw': {'eig_vals': None, 'energy': -4.251708984375},
#  'fault-subspace': {'eig_vals': array([-3.58536591-0.56862819j, -3.58536591+0.56862819j,
#           0.03028614+0.j        ]),
#   'eig_vecs': array([[ 0.44667277+9.87264370e-02j,  0.09872644+4.46672770e-01j,
#           -0.47072335-1.02217474e-17j],
#          [ 0.0706578 +2.03888428e-02j,  0.02038884+7.06578024e-02j,
#            0.79703385-2.98134299e-18j],
#          [-0.86931231-1.72117391e-01j, -0.17211739-8.69312315e-01j,
#           -0.37836037+8.51812282e-18j]]),
#   'H_tilde': array([[-0.39904785+0.j, -0.38476562+0.j, -0.32373047+0.j],
# ...
